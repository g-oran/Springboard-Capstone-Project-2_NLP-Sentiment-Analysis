# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from keras.preprocessing.sequence import pad_sequences
from keras.utils import np_utils
import gensim
import nltk
from gensim.models.word2vec import Word2Vec
import tensorflow as tf
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
nltk.download('stopwords')
import re
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Read the file
df3 = pd.read_csv('D:\GENEL\SPRINGBOARD\PROJECTS\CAPSTONE PROJECTS\CAPSTONE PROJECT-2/Reduced_Cleaned_Reviews_Home_and_Kitchen.csv')

# %%
df3['rating_class'] = df3['rating_class'].apply(lambda x: 0 if x == 'bad' else 1)
X = df3['clean_text']
y = df3['rating_class']

# %%
df3['clean_text'][:5]
# Out:
# 0    better bought would always one chilled ready g...
# 1    great pressure cooker several month since purc...
# 2    lightning deal good quart pot small anything f...
# 3    ergonomically designed work love design scoop ...
# 4    not sturdy son work ice cream shop recieved ic...
# Name: clean_text, dtype: object

# %% [markdown]
# ## Tokenizer

# %%
from keras.preprocessing.text import Tokenizer

samples = X
tokenizer = Tokenizer(lower=True, split=' ') # creates tokenizer
tokenizer.fit_on_texts(samples)  # builds the word index
sequences = tokenizer.texts_to_sequences(samples) #turns strings into list of integers
# word_index is a dictionary mapping words to an integer index
word_index = tokenizer.word_index 
print(f'Found {len(word_index)} unique tokens. ')
# Out:
# Found 20149 unique tokens.

# %%
max([max(sequence) for sequence in sequences])
# Out:
# 20149

# %%
# Each number is the index of the word in the order of word in original text
sequences[0]
# Out:
# [45,
#  319,
#  7,
#  166,
#  5,
#  2061,
#  590,
#  74,
#  19,
#  6,
#  350,
#  11,
#  147,
#  431,
#  3,
#  92,
#  48,
#  224,
#  89,
#  240,
#  477,
#  5,
#  978,
#  1,
#  27,
#  141,
#  89,
#  513,
#  508,
#  302,
#  768,
#  92,
#  151,
#  729,
#  1768,
#  77,
#  24,
#  11,
#  729,
#  1148,
#  3891,
#  147,
#  431,
#  1164,
#  94,
#  1165,
#  746,
#  729,
#  404,
#  229,
#  2,
#  4,
#  12,
#  16,
#  3892,
#  49,
#  768,
#  49,
#  1367,
#  895,
#  53,
#  1,
#  462,
#  789,
#  25,
#  8]

# %%
word_index
# Out:
# {'not': 1,
#  'wa': 2,
#  'use': 3,
#  'great': 4,
#  'one': 5,
#  'like': 6,
#  'would': 7,
#  'easy': 8,
#  'well': 9,
#  'good': 10,
#  'make': 11,
#  'doe': 12,
#  'work': 13,
#  'nice': 14,
#  'ha': 15,
#  'get': 16,
#  'product': 17,
#  'love': 18,
#  'really': 19,
#  'no': 20,
#  'time': 21,
#  'water': 22,
#  'set': 23,
#  'also': 24,
#  'clean': 25,
#  'cup': 26,
#  'much': 27,
#  'little': 28,
#  'used': 29,
#  'coffee': 30,
#  'look': 31,
#  'made': 32,
#  'thing': 33,
#  'vacuum': 34,
#  'using': 35,
#  'handle': 36,
#  'small': 37,
#  'kitchen': 38,
#  'even': 39,
#  'need': 40,
#  'quality': 41,
#  'pan': 42,
#  'size': 43,
#  'come': 44,
#  'better': 45,
#  'hold': 46,
#  'plastic': 47,
#  'keep': 48,
#  'put': 49,
#  'price': 50,
#  'perfect': 51,
#  'enough': 52,
#  'way': 53,
#  'easily': 54,
#  'two': 55,
#  'lot': 56,
#  'hand': 57,
#  'could': 58,
#  'first': 59,
#  'top': 60,
#  'fit': 61,
#  'take': 62,
#  'recommend': 63,
#  'bit': 64,
#  'design': 65,
#  'want': 66,
#  'feel': 67,
#  'lid': 68,
#  'big': 69,
#  'filter': 70,
#  'think': 71,
#  'food': 72,
#  'hot': 73,
#  'go': 74,
#  'item': 75,
#  'review': 76,
#  'year': 77,
#  'long': 78,
#  'pretty': 79,
#  'press': 80,
#  'towel': 81,
#  'without': 82,
#  'sturdy': 83,
#  'problem': 84,
#  'dishwasher': 85,
#  'back': 86,
#  'color': 87,
#  'large': 88,
#  'unit': 89,
#  'around': 90,
#  'still': 91,
#  'bowl': 92,
#  'job': 93,
#  'right': 94,
#  'oxo': 95,
#  'side': 96,
#  'looking': 97,
#  'since': 98,
#  'cleaning': 99,
#  'say': 100,
#  'tea': 101,
#  'see': 102,
#  'knife': 103,
#  'piece': 104,
#  'machine': 105,
#  'bottle': 106,
#  'something': 107,
#  'got': 108,
#  'heavy': 109,
#  'many': 110,
#  'pot': 111,
#  'floor': 112,
#  'last': 113,
#  'heat': 114,
#  'glass': 115,
#  'bag': 116,
#  'cooking': 117,
#  'however': 118,
#  'steam': 119,
#  'place': 120,
#  'though': 121,
#  'high': 122,
#  'bottom': 123,
#  'seems': 124,
#  'another': 125,
#  'best': 126,
#  'mug': 127,
#  'silicone': 128,
#  'hard': 129,
#  'light': 130,
#  'far': 131,
#  'sure': 132,
#  'know': 133,
#  'space': 134,
#  'find': 135,
#  'star': 136,
#  'tool': 137,
#  'room': 138,
#  'never': 139,
#  'steel': 140,
#  'buy': 141,
#  'new': 142,
#  'quite': 143,
#  'going': 144,
#  'day': 145,
#  'iron': 146,
#  'ice': 147,
#  'old': 148,
#  'overall': 149,
#  'part': 150,
#  'making': 151,
#  'fine': 152,
#  'le': 153,
#  'stainless': 154,
#  'found': 155,
#  'try': 156,
#  'different': 157,
#  'container': 158,
#  'store': 159,
#  'feature': 160,
#  'tried': 161,
#  'scale': 162,
#  'box': 163,
#  'every': 164,
#  'simple': 165,
#  'always': 166,
#  'give': 167,
#  'easier': 168,
#  'getting': 169,
#  'measuring': 170,
#  'drink': 171,
#  'oven': 172,
#  'actually': 173,
#  'thought': 174,
#  'dish': 175,
#  'safe': 176,
#  'cord': 177,
#  'cook': 178,
#  'wine': 179,
#  'highly': 180,
#  'counter': 181,
#  'grip': 182,
#  'metal': 183,
#  'anything': 184,
#  'plate': 185,
#  'wash': 186,
#  'issue': 187,
#  'excellent': 188,
#  'minute': 189,
#  'brush': 190,
#  'several': 191,
#  'weight': 192,
#  'baking': 193,
#  'cut': 194,
#  'everything': 195,
#  'gift': 196,
#  'maker': 197,
#  'inside': 198,
#  'dry': 199,
#  'grill': 200,
#  'idea': 201,
#  'may': 202,
#  'holder': 203,
#  'happy': 204,
#  'stick': 205,
#  'definitely': 206,
#  'house': 207,
#  'handy': 208,
#  'came': 209,
#  'cleaner': 210,
#  'surface': 211,
#  'turn': 212,
#  'worked': 213,
#  'quickly': 214,
#  'carpet': 215,
#  'able': 216,
#  'blade': 217,
#  'instruction': 218,
#  'recommended': 219,
#  'worth': 220,
#  'air': 221,
#  'attractive': 222,
#  'mold': 223,
#  'second': 224,
#  'soft': 225,
#  'cheap': 226,
#  'help': 227,
#  'might': 228,
#  'end': 229,
#  'amount': 230,
#  'month': 231,
#  'especially': 232,
#  'power': 233,
#  'comfortable': 234,
#  'home': 235,
#  'useful': 236,
#  'seem': 237,
#  'smaller': 238,
#  'cool': 239,
#  'storage': 240,
#  'area': 241,
#  'together': 242,
#  'egg': 243,
#  'fill': 244,
#  'perfectly': 245,
#  'longer': 246,
#  'button': 247,
#  'open': 248,
#  'ever': 249,
#  'nicely': 250,
#  'larger': 251,
#  'setting': 252,
#  'away': 253,
#  'three': 254,
#  'rack': 255,
#  'dirt': 256,
#  'cutting': 257,
#  'sheet': 258,
#  'pitcher': 259,
#  'stay': 260,
#  'done': 261,
#  'expensive': 262,
#  'nonstick': 263,
#  'plus': 264,
#  'let': 265,
#  'fun': 266,
#  'add': 267,
#  'nothing': 268,
#  'remove': 269,
#  'suction': 270,
#  'couple': 271,
#  'white': 272,
#  'almost': 273,
#  'microwave': 274,
#  'temperature': 275,
#  'received': 276,
#  'super': 277,
#  'lightweight': 278,
#  'taste': 279,
#  'kind': 280,
#  'probably': 281,
#  'yet': 282,
#  'either': 283,
#  'pillow': 284,
#  'amazon': 285,
#  'although': 286,
#  'juice': 287,
#  'board': 288,
#  'steamer': 289,
#  'designed': 290,
#  'beautiful': 291,
#  'shape': 292,
#  'sharp': 293,
#  'table': 294,
#  'durable': 295,
#  'inch': 296,
#  'brand': 297,
#  'solid': 298,
#  'shower': 299,
#  'money': 300,
#  'muffin': 301,
#  'extra': 302,
#  'canister': 303,
#  'kid': 304,
#  'model': 305,
#  'u': 306,
#  'read': 307,
#  'fact': 308,
#  'rather': 309,
#  'mop': 310,
#  'needed': 311,
#  'thick': 312,
#  'black': 313,
#  'cold': 314,
#  'blender': 315,
#  'hook': 316,
#  'thin': 317,
#  'said': 318,
#  'bought': 319,
#  'people': 320,
#  'etc': 321,
#  'cost': 322,
#  'french': 323,
#  'point': 324,
#  'instead': 325,
#  'family': 326,
#  'base': 327,
#  'bad': 328,
#  'regular': 329,
#  'full': 330,
#  'maybe': 331,
#  'edge': 332,
#  'clear': 333,
#  'mean': 334,
#  'difficult': 335,
#  'juicer': 336,
#  'red': 337,
#  'door': 338,
#  'result': 339,
#  'must': 340,
#  'wall': 341,
#  'garlic': 342,
#  'addition': 343,
#  'cute': 344,
#  'toaster': 345,
#  'battery': 346,
#  'pick': 347,
#  'us': 348,
#  'awesome': 349,
#  'fast': 350,
#  'vegetable': 351,
#  'week': 352,
#  'material': 353,
#  'pop': 354,
#  'cover': 355,
#  'strong': 356,
#  'napkin': 357,
#  'update': 358,
#  'quick': 359,
#  'liquid': 360,
#  'trying': 361,
#  'spoon': 362,
#  'type': 363,
#  'warm': 364,
#  'whole': 365,
#  'hanger': 366,
#  'wonderful': 367,
#  'bread': 368,
#  'mat': 369,
#  'ok': 370,
#  'attachment': 371,
#  'favorite': 372,
#  'hang': 373,
#  'simply': 374,
#  'others': 375,
#  'half': 376,
#  'took': 377,
#  'low': 378,
#  'expect': 379,
#  'salad': 380,
#  'meat': 381,
#  'hour': 382,
#  'device': 383,
#  'head': 384,
#  'prefer': 385,
#  'already': 386,
#  'run': 387,
#  'left': 388,
#  'four': 389,
#  'fan': 390,
#  'recipe': 391,
#  'cupcake': 392,
#  'free': 393,
#  'wanted': 394,
#  'convenient': 395,
#  'reason': 396,
#  'decent': 397,
#  'huge': 398,
#  'fairly': 399,
#  'pleased': 400,
#  'start': 401,
#  'cookware': 402,
#  'mess': 403,
#  'fruit': 404,
#  'close': 405,
#  'stand': 406,
#  'real': 407,
#  'timer': 408,
#  'slice': 409,
#  'hair': 410,
#  'jar': 411,
#  'gadget': 412,
#  'wish': 413,
#  'flat': 414,
#  'sugar': 415,
#  'seal': 416,
#  'short': 417,
#  'tray': 418,
#  'purchase': 419,
#  'usually': 420,
#  'line': 421,
#  'soap': 422,
#  'fresh': 423,
#  'next': 424,
#  'control': 425,
#  'hole': 426,
#  'bathroom': 427,
#  'vac': 428,
#  'hose': 429,
#  'owned': 430,
#  'cream': 431,
#  'least': 432,
#  'expected': 433,
#  'stuff': 434,
#  'washing': 435,
#  'often': 436,
#  'function': 437,
#  'foot': 438,
#  'anyone': 439,
#  'drawer': 440,
#  'completely': 441,
#  'wife': 442,
#  'ground': 443,
#  'push': 444,
#  'pour': 445,
#  'mine': 446,
#  'case': 447,
#  'value': 448,
#  'pet': 449,
#  'touch': 450,
#  'move': 451,
#  'impressed': 452,
#  'purpose': 453,
#  'ounce': 454,
#  'cheese': 455,
#  'cookie': 456,
#  'rubber': 457,
#  'pull': 458,
#  'single': 459,
#  'allows': 460,
#  'complaint': 461,
#  'deal': 462,
#  'someone': 463,
#  'tell': 464,
#  'veggie': 465,
#  'oil': 466,
#  'liked': 467,
#  'cooker': 468,
#  'included': 469,
#  'pepper': 470,
#  'option': 471,
#  'save': 472,
#  'apart': 473,
#  'basic': 474,
#  'kettle': 475,
#  'smell': 476,
#  'replacement': 477,
#  'went': 478,
#  'picture': 479,
#  'hoover': 480,
#  'difference': 481,
#  'standard': 482,
#  'compact': 483,
#  'peeler': 484,
#  'leave': 485,
#  'manual': 486,
#  'else': 487,
#  'extremely': 488,
#  'functional': 489,
#  'thermos': 490,
#  'powerful': 491,
#  'absolutely': 492,
#  'exactly': 493,
#  'grinder': 494,
#  'smooth': 495,
#  'provided': 496,
#  'slightly': 497,
#  'dust': 498,
#  'husband': 499,
#  'sink': 500,
#  'similar': 501,
#  'cake': 502,
#  'level': 503,
#  'washed': 504,
#  'ring': 505,
#  'lunch': 506,
#  'bigger': 507,
#  'buying': 508,
#  'ball': 509,
#  'course': 510,
#  'paper': 511,
#  'sized': 512,
#  'compared': 513,
#  'green': 514,
#  'working': 515,
#  'disappointed': 516,
#  'cooky': 517,
#  'sometimes': 518,
#  'outside': 519,
#  'snap': 520,
#  'keeping': 521,
#  'grind': 522,
#  'empty': 523,
#  'break': 524,
#  'flimsy': 525,
#  'pizza': 526,
#  'bed': 527,
#  'accurate': 528,
#  'reviewer': 529,
#  'life': 530,
#  'appliance': 531,
#  'five': 532,
#  'purchased': 533,
#  'loud': 534,
#  'utensil': 535,
#  'test': 536,
#  'spatula': 537,
#  'oz': 538,
#  'finish': 539,
#  'grater': 540,
#  'thermometer': 541,
#  'ingredient': 542,
#  'heater': 543,
#  'experience': 544,
#  'built': 545,
#  'unfortunately': 546,
#  'sample': 547,
#  'slicer': 548,
#  'unless': 549,
#  'choice': 550,
#  'fall': 551,
#  'cat': 552,
#  'evenly': 553,
#  'yes': 554,
#  'bar': 555,
#  'supposed': 556,
#  'tiny': 557,
#  'party': 558,
#  'holding': 559,
#  'stuck': 560,
#  'fantastic': 561,
#  'leak': 562,
#  'pineapple': 563,
#  'hanging': 564,
#  'finger': 565,
#  'display': 566,
#  'night': 567,
#  'clothes': 568,
#  'dinner': 569,
#  'order': 570,
#  'wrong': 571,
#  'number': 572,
#  'surprised': 573,
#  'morning': 574,
#  'mattress': 575,
#  'friend': 576,
#  'measure': 577,
#  'chocolate': 578,
#  'soup': 579,
#  'dog': 580,
#  'style': 581,
#  'noticed': 582,
#  'otherwise': 583,
#  'started': 584,
#  'upright': 585,
#  'potato': 586,
#  'spill': 587,
#  'looked': 588,
#  'rug': 589,
#  'ready': 590,
#  'change': 591,
#  'ease': 592,
#  'degree': 593,
#  'due': 594,
#  'brown': 595,
#  'replace': 596,
#  'finally': 597,
#  'tight': 598,
#  'direction': 599,
#  'wet': 600,
#  'cleanup': 601,
#  'flexible': 602,
#  'company': 603,
#  'seemed': 604,
#  'bath': 605,
#  'waffle': 606,
#  'travel': 607,
#  'excited': 608,
#  'rest': 609,
#  'deep': 610,
#  'turned': 611,
#  'brew': 612,
#  'bin': 613,
#  'putting': 614,
#  'arrived': 615,
#  'past': 616,
#  'given': 617,
#  'curtain': 618,
#  'amazing': 619,
#  'whatever': 620,
#  'stove': 621,
#  'fabric': 622,
#  'double': 623,
#  'carrot': 624,
#  'straw': 625,
#  'scoop': 626,
#  'okay': 627,
#  'held': 628,
#  'throw': 629,
#  'plenty': 630,
#  'bright': 631,
#  'corner': 632,
#  'spot': 633,
#  'careful': 634,
#  'enjoy': 635,
#  'tip': 636,
#  'pro': 637,
#  'system': 638,
#  'closet': 639,
#  'guess': 640,
#  'ago': 641,
#  'cotton': 642,
#  'flavor': 643,
#  'cube': 644,
#  'serving': 645,
#  'worry': 646,
#  'sleek': 647,
#  'bos': 648,
#  'slow': 649,
#  'front': 650,
#  'pad': 651,
#  'cork': 652,
#  'slide': 653,
#  'drip': 654,
#  'shelf': 655,
#  'milk': 656,
#  'wood': 657,
#  'screw': 658,
#  'onto': 659,
#  'care': 660,
#  'note': 661,
#  'blue': 662,
#  'main': 663,
#  'hope': 664,
#  'popcorn': 665,
#  'meal': 666,
#  'show': 667,
#  'rice': 668,
#  'decided': 669,
#  'seen': 670,
#  'manufacturer': 671,
#  'opinion': 672,
#  'cheaper': 673,
#  'reading': 674,
#  'cleaned': 675,
#  'mill': 676,
#  'holiday': 677,
#  'wide': 678,
#  'wait': 679,
#  'sort': 680,
#  'cooked': 681,
#  'gave': 682,
#  'dispenser': 683,
#  'certainly': 684,
#  'caddy': 685,
#  'sponge': 686,
#  'dinnerware': 687,
#  'name': 688,
#  'switch': 689,
#  'allow': 690,
#  'entire': 691,
#  'matter': 692,
#  'carry': 693,
#  'brita': 694,
#  'effective': 695,
#  'quiet': 696,
#  'basket': 697,
#  'clip': 698,
#  'awkward': 699,
#  'twice': 700,
#  'loved': 701,
#  'tank': 702,
#  'opening': 703,
#  'taking': 704,
#  'x': 705,
#  'fry': 706,
#  'speed': 707,
#  'faster': 708,
#  'mind': 709,
#  'fridge': 710,
#  'digital': 711,
#  'lock': 712,
#  'service': 713,
#  'heating': 714,
#  'noise': 715,
#  'bissell': 716,
#  'drying': 717,
#  'chicken': 718,
#  'construction': 719,
#  'important': 720,
#  'variety': 721,
#  'pay': 722,
#  'modern': 723,
#  'daily': 724,
#  'electric': 725,
#  'stain': 726,
#  'dyson': 727,
#  'neck': 728,
#  'frozen': 729,
#  'pain': 730,
#  'person': 731,
#  'daughter': 732,
#  'wheel': 733,
#  'stair': 734,
#  'bodum': 735,
#  'cloth': 736,
#  'foam': 737,
#  'pressure': 738,
#  'sound': 739,
#  'spout': 740,
#  'car': 741,
#  'book': 742,
#  'warranty': 743,
#  'immediately': 744,
#  'espresso': 745,
#  'added': 746,
#  'trouble': 747,
#  'stylish': 748,
#  'sit': 749,
#  'customer': 750,
#  'believe': 751,
#  'filled': 752,
#  'solution': 753,
#  'separate': 754,
#  'eat': 755,
#  'properly': 756,
#  'elegant': 757,
#  'skillet': 758,
#  'multiple': 759,
#  'apple': 760,
#  'produce': 761,
#  'glad': 762,
#  'effort': 763,
#  'batch': 764,
#  'duty': 765,
#  'tile': 766,
#  'cuisinart': 767,
#  'freezer': 768,
#  'saw': 769,
#  'negative': 770,
#  'roll': 771,
#  'step': 772,
#  'performance': 773,
#  'whisk': 774,
#  'liner': 775,
#  'version': 776,
#  'poor': 777,
#  'devil': 778,
#  'drop': 779,
#  'sandwich': 780,
#  'dryer': 781,
#  'stop': 782,
#  'practical': 783,
#  'packaging': 784,
#  'cabinet': 785,
#  'later': 786,
#  'available': 787,
#  'lovely': 788,
#  'block': 789,
#  'tongs': 790,
#  'coating': 791,
#  'mix': 792,
#  'leaf': 793,
#  'heavier': 794,
#  'hate': 795,
#  'flaw': 796,
#  'vacuuming': 797,
#  'insert': 798,
#  'along': 799,
#  'unlike': 800,
#  'lower': 801,
#  'limited': 802,
#  'package': 803,
#  'vine': 804,
#  'candy': 805,
#  'felt': 806,
#  'live': 807,
#  'everyday': 808,
#  'traditional': 809,
#  'beverage': 810,
#  'strip': 811,
#  'coming': 812,
#  'spray': 813,
#  'except': 814,
#  'loose': 815,
#  'bake': 816,
#  'reach': 817,
#  'true': 818,
#  'breeze': 819,
#  'special': 820,
#  'fold': 821,
#  'particularly': 822,
#  'across': 823,
#  'position': 824,
#  'build': 825,
#  'six': 826,
#  'pound': 827,
#  'pump': 828,
#  'broke': 829,
#  'dough': 830,
#  'onion': 831,
#  'baked': 832,
#  'ceramic': 833,
#  'bamboo': 834,
#  'release': 835,
#  'average': 836,
#  'running': 837,
#  'grease': 838,
#  'honest': 839,
#  'toast': 840,
#  'con': 841,
#  'mixer': 842,
#  'guest': 843,
#  'neat': 844,
#  'measurement': 845,
#  'normal': 846,
#  'soon': 847,
#  'range': 848,
#  'priced': 849,
#  'rating': 850,
#  'colander': 851,
#  'round': 852,
#  'placed': 853,
#  'including': 854,
#  'various': 855,
#  'perhaps': 856,
#  'near': 857,
#  'middle': 858,
#  'nearly': 859,
#  'likely': 860,
#  'truly': 861,
#  'helpful': 862,
#  'process': 863,
#  'medium': 864,
#  'keurig': 865,
#  'mechanism': 866,
#  'mostly': 867,
#  'requires': 868,
#  'capacity': 869,
#  'anyway': 870,
#  'kept': 871,
#  'scarf': 872,
#  'arm': 873,
#  'removed': 874,
#  'scratch': 875,
#  'center': 876,
#  'consider': 877,
#  'claim': 878,
#  'spend': 879,
#  'original': 880,
#  'ray': 881,
#  'apartment': 882,
#  'pack': 883,
#  'child': 884,
#  'relatively': 885,
#  'batter': 886,
#  'higher': 887,
#  'carafe': 888,
#  'somewhat': 889,
#  'inexpensive': 890,
#  'lack': 891,
#  'hit': 892,
#  'filtered': 893,
#  'loaf': 894,
#  'portion': 895,
#  'drain': 896,
#  'within': 897,
#  'figure': 898,
#  'butter': 899,
#  'drinking': 900,
#  'drinker': 901,
#  'plug': 902,
#  'spice': 903,
#  'check': 904,
#  'become': 905,
#  'behind': 906,
#  'replaced': 907,
#  'bonus': 908,
#  'call': 909,
#  'bagless': 910,
#  'removable': 911,
#  'motor': 912,
#  'straight': 913,
#  'tall': 914,
#  'ordered': 915,
#  'forward': 916,
#  'decker': 917,
#  'blend': 918,
#  'chair': 919,
#  'quart': 920,
#  'sitting': 921,
#  'versatile': 922,
#  'attached': 923,
#  'label': 924,
#  'improvement': 925,
#  'user': 926,
#  'plan': 927,
#  'safety': 928,
#  'advertised': 929,
#  'cutter': 930,
#  'ideal': 931,
#  'fancy': 932,
#  'brewer': 933,
#  'tfal': 934,
#  'plunger': 935,
#  'opener': 936,
#  'giving': 937,
#  'flour': 938,
#  'boiling': 939,
#  'covered': 940,
#  'tend': 941,
#  'brewing': 942,
#  'waste': 943,
#  'handheld': 944,
#  'furniture': 945,
#  'appears': 946,
#  'lift': 947,
#  'ended': 948,
#  'serve': 949,
#  'prevent': 950,
#  'based': 951,
#  'basically': 952,
#  'cast': 953,
#  'adjustable': 954,
#  'bedroom': 955,
#  'reasonable': 956,
#  'household': 957,
#  'slot': 958,
#  'dirty': 959,
#  'mentioned': 960,
#  'chef': 961,
#  'summer': 962,
#  'stone': 963,
#  'slicing': 964,
#  'body': 965,
#  'support': 966,
#  'removing': 967,
#  'previous': 968,
#  'orange': 969,
#  'ability': 970,
#  'wow': 971,
#  'wrap': 972,
#  'pasta': 973,
#  'bend': 974,
#  'lighter': 975,
#  'messy': 976,
#  'odor': 977,
#  'wear': 978,
#  'recently': 979,
#  'possible': 980,
#  'broken': 981,
#  'filling': 982,
#  'major': 983,
#  'assembly': 984,
#  'office': 985,
#  'height': 986,
#  'griddle': 987,
#  'everyone': 988,
#  'positive': 989,
#  'avoid': 990,
#  'feeling': 991,
#  'today': 992,
#  'required': 993,
#  'catch': 994,
#  'opened': 995,
#  'fair': 996,
#  'laundry': 997,
#  'sleep': 998,
#  'hamper': 999,
#  'task': 1000,
#  ...}

# %%
# We reverse it, mapping integer indices to words
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
# We decode the review; note that our indices were offset by 3
# because 0, 1 and 2 are reserved indices for "padding", "start of sequence", and "unknown".
decoded_review = ' '.join([reverse_word_index.get(i - 3, '?') for i in sequences[0]])

# %%
def sequence_to_text(sequence):
    words =  [reverse_word_index.get(letter) for letter in sequence]
    return words

my_text = list(map(sequence_to_text, sequences))

# %%
print(sequences[0])
# Out:
# [45, 319, 7, 166, 5, 2061, 590, 74, 19, 6, 350, 11, 147, 431, 3, 92, 48, 224, 89, 240, 477, 5, 978, 1, 27, 141, 89, 513, 508, 302, 768, 92, 151, 729, 1768, 77, 24, 11, 729, 1148, 3891, 147, 431, 1164, 94, 1165, 746, 729, 404, 229, 2, 4, 12, 16, 3892, 49, 768, 49, 1367, 895, 53, 1, 462, 789, 25, 8]

# %% [markdown]
# ## Word2Vec and Simple Neural Network

# %%
word2vec = gensim.models.Word2Vec(my_text,
                                  size=100,
                                  window=10,
                                  min_count=1)
word2vec.train(my_text, total_examples=25026, epochs=10)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "
# (4897161, 5392210)

# %%
similar_words = {search_term: [item[0] for item in word2vec.wv.most_similar([search_term], topn=5)]
                  for search_term in ['feel', 'good', 'product', 'cheap', 'beauty', 'bad', 'skin','fragrance']}
similar_words
# Out:
# {'feel': ['feeling', 'felt', 'soft', 'substantial', 'material'],
#  'good': ['decent', 'great', 'nice', 'excellent', 'reasonable'],
#  'product': ['winner',
#   'toolsgadgets',
#   'disorganization',
#   'oxo',
#   'highperforming'],
#  'cheap': ['flimsy', 'fragile', 'plastic', 'walmart', 'exponentially'],
#  'beauty': ['chic', 'toned', 'minimalist', 'decorated', 'classy'],
#  'bad': ['complain', 'okay', 'theory', 'fulfill', 'bother'],
#  'skin': ['peeling', 'starch', 'slicing', 'dicing', 'pit'],
#  'fragrance': ['fizz', 'los', 'angeles', 'geyser', 'rainwater']}

# %%
from sklearn.manifold import TSNE

words = sum([[k] + v for k, v in similar_words.items()], [])
wvs = word2vec.wv[words]

tsne = TSNE(n_components=2, random_state=0, n_iter=10000, perplexity=2)
np.set_printoptions(suppress=True)
T = tsne.fit_transform(wvs)
labels = words

plt.figure(figsize=(14, 8))
plt.scatter(T[:, 0], T[:, 1], c='orange', edgecolors='r')
for label, x, yt in zip(labels, T[:, 0], T[:, 1]):
    plt.annotate(label, xy=(x+1, yt+1), xytext=(0, 0), textcoords='offset points')

# %%
len(word_index.keys())
# Out:
# 20149

# %%
len(word2vec.wv.vocab)
# Out:
# 20149

# %% [markdown]
# So we created word vectors using Word2Vec and the model has 20149 unique words where each word has a vector length of 100
#
# Now we are going to use these dense vectors - word embeddings - in a simple neural network to predict

# %%
from keras.preprocessing.sequence import pad_sequences
max_length = 200 # fix the length of each review 
max_words = len(word_index.keys()) # fix number of words 

training_samples = 6000
validation_samples = 2933
data = pad_sequences(sequences, maxlen=max_length)

#labels = np.asarray(y)
print('Shape of data tensor:', data.shape)
print('Shape of label tensor:', y.shape)

# Split the data into a training set and a validation set
# But first, shuffle the data, since we started from data
# where sample are ordered (all negative first, then all positive).
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = y[indices]

x_train = data[:training_samples]
y_train = y[:training_samples]
x_val = data[training_samples: training_samples + validation_samples]
y_val = y[training_samples: training_samples + validation_samples]
print('Shape of training data: ', x_train.shape)
print('Shape of validation data: ', x_val.shape)
# Out:
# Shape of data tensor: (8933, 200)
# Shape of label tensor: (8933,)
# Shape of training data:  (6000, 200)
# Shape of validation data:  (2933, 200)

# %%
embedding_dim = 100

embedding_matrix = np.zeros((max_words+1, embedding_dim))
for word , i in word_index.items():
    embedding_vector = word2vec.wv[word]
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# The Embedding layer is best understood as a dictionary mapping integer indices (which stand for specific words) to dense vectors. It takes as input integers, it looks up these integers into an internal dictionary, and it returns the associated vectors. It's effectively a dictionary lookup.
#
# The Embedding layer takes as input a 2D tensor of integers, of shape (samples, sequence_length), where each entry is a sequence of integers. It can embed sequences of variable lengths, so for instance we could feed into our embedding layer above batches that could have shapes (32, 10) (batch of 32 sequences of length 10) or (64, 15) (batch of 64 sequences of length 15). All sequences in a batch must have the same length, though (since we need to pack them into a single tensor), so sequences that are shorter than others should be padded with zeros, and sequences that are longer should be truncated.
#
# This layer returns a 3D floating point tensor, of shape (samples, sequence_length, embedding_dimensionality). Such a 3D tensor can then be processed by a RNN layer or a 1D convolution layer
#
# When you instantiate an Embedding layer, its weights (its internal dictionary of token vectors) are initially random, just like with any other layer. During training, these word vectors will be gradually adjusted via backpropagation, structuring the space into something that the downstream model can exploit. Once fully trained, your embedding space will show a lot of structure -- a kind of structure specialized for the specific problem you were training your model for.

# %%
embedding_matrix.shape
# Out:
# (20150, 100)

# %%
from keras.models import Sequential
from keras.layers import Embedding, Flatten, Dense


model = Sequential()
model.add(Embedding(max_words+1, embedding_dim, input_length=max_length))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 200, 100)          2015000
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 20000)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                640032
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,655,065
# Trainable params: 2,655,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers[0].set_weights([embedding_matrix])
model.layers[0].trainable = False

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'